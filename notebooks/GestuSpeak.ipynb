# %% [markdown]
# <a href="https://colab.research.google.com/github/NotRay-67/GestuSpeak/blob/main/GestuSpeak.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install -q kaggle
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-98f0d38b-5346-426b-9f26-88a8b9bb8796" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-98f0d38b-5346-426b-9f26-88a8b9bb8796">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d "prathumarikeri/indian-sign-language-isl"
# Out:
# ...
#  97% 271M/281M [00:01<00:00, 157MB/s]
# 100% 281M/281M [00:02<00:00, 141MB/s]

# %%
# !mkdir /content/drive/MyDrive/dataset/signlanguage
# !unzip /content/indian-sign-language-isl.zip -d /content/drive/MyDrive/dataset/signlanguage

# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import os
import glob
import sklearn
from PIL import Image
import cv2

# %% [markdown]
# ## Data preprocessing

# %%
file_path = '/content/drive/MyDrive/dataset/signlanguage/Indian'

files = glob.glob(os.path.join("file_path", "*"))

# %%
img = cv2.imread("/content/10.jpg")
print(f"image Height and width {img.shape[:2]}")
print(f"Img dtype {img.dtype}")
print(f"Pixel value for some pixel: {img[100,100]}")
roi = img[100:500,200:700]
img1 = cv2.resize(img,(800,800),interpolation=cv2.INTER_LINEAR)
img1
# Out:
# image Height and width (128, 128)
# Img dtype uint8
# Pixel value for some pixel: [21 11 11]
# array([[[22, 10, 10],
#         [22, 10, 10],
#         [22, 10, 10],
#         ...,
#         [31, 44, 20],
#         [31, 44, 20],
#         [31, 44, 20]],
#
#        [[22, 10, 10],
#         [22, 10, 10],
#         [22, 10, 10],
#         ...,
#         [31, 44, 20],
#         [31, 44, 20],
#         [31, 44, 20]],
#
#        [[22, 10, 10],
#         [22, 10, 10],
#         [22, 10, 10],
#         ...,
#         [31, 44, 20],
#         [31, 44, 20],
#         [31, 44, 20]],
#
#        ...,
#
#        [[25, 37, 17],
#         [25, 37, 17],
#         [25, 37, 17],
#         ...,
#         [36, 65, 26],
#         [36, 65, 26],
#         [36, 65, 26]],
#
#        [[25, 37, 17],
#         [25, 37, 17],
#         [25, 37, 17],
#         ...,
#         [36, 65, 26],
#         [36, 65, 26],
#         [36, 65, 26]],
#
#        [[25, 37, 17],
#         [25, 37, 17],
#         [25, 37, 17],
# ...
